# %% [markdown]
# Question1.
#
# Write a function that stutters a word as if someone is struggling to read it. The
# first two letters are repeated twice with an ellipsis ... and space after each, and then the
# word is pronounced with a question mark ?.
# Examples
# stutter('incredible') ➞ 'in... in... incredible?'
# stutter('enthusiastic') ➞ 'en... en... enthusiastic?'
# stutter('outstanding') ➞ 'ou... ou... outstanding?'
#
# Hint :- Assume all input is in lower case and at least two characters long.

# %%
def stutters(word):
    word = word.lower()
    w2 = word[:2]+'... '+ word[:2]+'... '+word+'?'
    print(w2)

# %%
stutters('incredible')
# Out:
# in... in... incredible?

# %% [markdown]
# Question 2.
#
# Create a function that takes an angle in radians and returns the corresponding
# angle in degrees rounded to one decimal place.
# Examples
# radians_to_degrees(1) ➞ 57.3
# radians_to_degrees(20) ➞ 1145.9
# radians_to_degrees(50) ➞ 2864.8

# %%
def rad_ang(radian):
    angle = radian * 57.296
    print('{:.1f}'.format(angle))

# %%
rad_ang(1)
rad_ang(20)
rad_ang(50)
# Out:
# 57.3
# 1145.9
# 2864.8

# %% [markdown]
# Question 3.
#
# In this challenge, establish if a given integer num is a Curzon number. If 1 plus 2 elevated to num is exactly divisible by 1 plus 2 multiplied by num, then num is a Curzon number.
# Given a non-negative integer num, implement a function that returns True if num is a Curzon number, or False otherwise.
# Examples
# is_curzon(5) ➞ True
#  2 ** 5 + 1 = 33
#  2 * 5 + 1 = 11
#  33 is a multiple of 11
# is_curzon(10) ➞ False
#  2 ** 10 + 1 = 1025
#  2 * 10 + 1 = 21
#  1025 is not a multiple of 21
# is_curzon(14) ➞ True
#  2 ** 14 + 1 = 16385
#  2 * 14 + 1 = 29
#  16385 is a multiple of 29

# %%
def curzon(n):
    x = 2 ** n +1
    y = 2 * n +1
    if x%y == 0:
        return True
    else:
        return False

# %%
print(f'curson_5 :{curzon(5)} , curson_10 :{curzon(10)} , curson_14 :{curzon(14)}')
# Out:
# curson_5 :True , curson_10 :False , curson_14 :True

# %% [markdown]
# Question 4.Given the side length x find the area of a hexagon.
#
# Examples
# area_of_hexagon(1) ➞ 2.6
# area_of_hexagon(2) ➞ 10.4
# area_of_hexagon(3) ➞ 23.4

# %%
from IPython.display import Image
Image(filename='Hexagon_Area.jpg')

# %%
def Hexagon_Area(x):
    Area = ((3*(3**(1/2)))*(x**2))/2
    print('{:.1f}'.format(Area))

# %%
Hexagon_Area(1)
Hexagon_Area(2)
Hexagon_Area(3)
# Out:
# 2.6
# 10.4
# 23.4

# %% [markdown]
# Question 5.
#
# Create a function that returns a base-2 (binary) representation of a base-10
# (decimal) string number. To convert is simple: ((2) means base-2 and (10) means base-10)
# 010101001(2) = 1 + 8 + 32 + 128.
# Going from right to left, the value of the most right bit is 1, now from that every bit to the left
# will be x2 the value, value of an 8 bit binary numbers are (256, 128, 64, 32, 16, 8, 4, 2, 1).
# Examples
# binary(1) ➞ '1'
#  1*1 = 1
# binary(5) ➞ '101'
#  1*1 + 1*4 = 5
# binary(10) ➞'1010'
#  1*2 + 1*8 = 10

# %%
def binary(n):
    x = int(n)
    if x == 0:
        return '0'
    binary = ''
    while x > 0:
        binary = str(x % 2) + binary
        x = x // 2
    return binary

# %%
print(f'Binary_1 :{binary(1)} ,Binary_5 :{binary(5)} ,Binary_10 :{binary(10)}')
# Out:
# Binary_1 :1 ,Binary_5 :101 ,Binary_10 :1010
